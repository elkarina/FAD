# %% [markdown]
# # Общеуниверситетский факультатив "Анализ данных"

# %% [markdown]
# # Тема 2. Исследование взаимосвязей переменных

# %% [markdown]
# * [1. Таблицы сопряжённости](#chapter1)
# * [2. Статистический тест Хи-квадрат](#chapter2)
# * [3. Тесты на нормальность](#chapter3)
# * [4. Корреляционный анализ](#chapter4)
# * [5. Частная корреляция](#chapter5)
# * [6. Визуализация корреляций](#chapter6)

# %%
# !pip install pingouin

import pandas as pd
from scipy import stats
from math import sqrt
import matplotlib.pyplot as plt
import pingouin as pg
from scipy.stats import pointbiserialr, norm
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Источник данных:  [Global Innovation Index](https://www.wipo.int/en/web/global-innovation-index)
#
# Файл `WIPO-GII.xlsx` содержит панельные данные за 3 года: 2020, 2021, 2022.

# %% [markdown]
# Список переменных:
# - Business environment
# - Business sophistication index
# - Citable documents H-index
# - Creative goods and services
# - Creative goods exports, % total trade
# - Creative outputs index
# - Cultural and creative services exports, % total trade
# - Domestic market scale, bn PPP (U.S. dollars)
# - Ease of getting credit
# - Ease of starting a business
# - Ecological sustainability
# - Expenditure on education, % GDP
# - Firms offering formal training, %
# - General infrastructure
# - Global Innovation Index
# - Government effectiveness
# - Government's online service
# - Graduates in science and engineering, %
# - Gross expenditure on R&D, % GDP
# - High-tech exports, % total trade
# - High-tech imports, % total trade
# - High-tech manufacturing, %
# - Human capital and research index
# - Information and Communications Technology access
# - Information and Communications Technology services exports, % total trade
# - Information and Communications Technology services imports, % total trade
# - Information and Communications Technology use
# - Infrastructure index
# - Intangible assets
# - Joint venture/strategic alliance deals/bn PPP (U.S. dollars) GDP
# - Knowledge absorption
# - Knowledge and technology outputs index
# - Knowledge workers
# - Knowledge-intensive employment, %
# - Logistics performance
# - Market sophistication index
# - Mobile app creation/bn PPP (U.S. dollars) GDP
# - Online creativity
# - PISA scales in reading, maths and science
# - Political and operational stability
# - Political environment
# - Pupil-teacher ratio, secondary
# - QS university ranking average score of top 3 universities
# - Research and development (R&D)
# - Scientific and technical articles/bn PPP (U.S. dollars) GDP
# - Software spending, % GDP
# - Tertiary education
# - Tertiary enrolment, % gross
# - University-industry R&D collaboration
# - Region
# - Euro area
# - European Union
# - OECD members
# - Least developed countries
# - Income

# %%
df = pd.read_excel('WIPO-GII.xlsx')
df
# Out:
#                   Country  Business environment_2020  \
# 0           Cote d'Ivoire                       70.8
# 1                 Czechia                       81.1
# 2        Egypt, Arab Rep.                       65.0
# 3    Hong Kong SAR, China                       81.9
# 4      Iran, Islamic Rep.                       51.4
# ..                    ...                        ...
# 134              Paraguay                       59.0
# 135                  Peru                       64.3
# 136   Trinidad and Tobago                       68.5
# 137         United States                       91.0
# 138               Uruguay                       71.6
#
#      Business environment_2021  Business environment_2022  \
# 0                         70.8                       48.3
# 1                         81.1                       42.1
# 2                         65.0                       45.0
# 3                         81.9                       69.7
# 4                         51.4                       13.3
# ..                         ...                        ...
# 134                       59.0                       28.8
# 135                       64.3                       50.4
# 136                       68.5                       47.6
# 137                       91.0                       75.3
# 138                       71.6                       64.2
#
#      Business sophistication index_2020  Business sophistication index_2021  \
# 0                                  19.7                                20.9
# 1                                  46.2                                43.5
# 2                                  18.7                                18.0
# 3                                  45.4                                45.2
# 4                                  17.9                                16.5
# ..                                  ...                                 ...
# 134                                22.2                                25.4
# 135                                33.8                                34.3
# 136                                18.0                                18.3
# 137                                62.8                                63.0
# 138                                22.1                                22.4
#
#      Business sophistication index_2022  Citable documents H-index_2020  \
# 0                                  21.8                             6.3
# 1                                  46.2                            29.8
# 2                                  20.4                            17.4
# 3                                  46.7                            36.5
# 4                                  18.6                            19.7
# ..                                  ...                             ...
# 134                                23.1                             4.2
# 135                                32.1                            13.8
# 136                                20.5                             5.0
# 137                                64.5                           100.0
# 138                                28.6                            11.4
#
#      Citable documents H-index_2021  Citable documents H-index_2022  ...  \
# 0                               6.1                             5.1  ...
# 1                              30.3                            30.4  ...
# 2                              17.7                            18.0  ...
# 3                              37.3                            38.4  ...
# 4                              20.5                            22.1  ...
# ..                              ...                             ...  ...
# 134                             4.0                             3.2  ...
# 135                            14.3                            14.4  ...
# 136                             4.9                             4.0  ...
# 137                           100.0                           100.0  ...
# 138                            11.2                            10.4  ...
#
#      University-industry R&D collaboration_2021  \
# 0                                          38.1
# 1                                          53.7
# 2                                          44.3
# 3                                          61.3
# 4                                          26.7
# ..                                          ...
# 134                                        24.5
# 135                                        31.4
# 136                                        33.3
# 137                                        74.4
# 138                                        39.5
#
#      University-industry R&D collaboration_2022                      Region  \
# 0                                          38.5          Sub-Saharan Africa
# 1                                          59.1       Europe & Central Asia
# 2                                          47.0  Middle East & North Africa
# 3                                          62.9         East Asia & Pacific
# 4                                          27.7  Middle East & North Africa
# ..                                          ...                         ...
# 134                                        26.8   Latin America & Caribbean
# 135                                        32.7   Latin America & Caribbean
# 136                                        33.6   Latin America & Caribbean
# 137                                        79.6               North America
# 138                                        42.7   Latin America & Caribbean
#
#                           Region2  Euro area  European Union  OECD members  \
# 0              Sub-Saharan Africa          0               0             0
# 1                          Europe          0               1             1
# 2    Middle East and North Africa          0               0             0
# 3                    Asia-Pacific          0               0             0
# 4    Middle East and North Africa          0               0             0
# ..                            ...        ...             ...           ...
# 134                      Americas          0               0             0
# 135                      Americas          0               0             0
# 136                      Americas          0               0             0
# 137                      Americas          0               0             1
# 138                      Americas          0               0             0
#
#      Least developed countries         Income  High income
# 0                            0  middle income            0
# 1                            0    high income            1
# 2                            0  middle income            0
# 3                            0    high income            1
# 4                            0  middle income            0
# ..                         ...            ...          ...
# 134                          0  middle income            0
# 135                          0  middle income            0
# 136                          0    high income            1
# 137                          0    high income            1
# 138                          0    high income            1
#
# [139 rows x 156 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Columns: 156 entries, Country to High income
# dtypes: float64(147), int64(5), object(4)
# memory usage: 169.5+ KB

# %%
df.info(verbose=True, show_counts=True)  # чтобы отобразить информацию обо всех переменных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 156 columns):
#  #    Column                                                                          Non-Null Count  Dtype
# ---   ------                                                                          --------------  -----
#  0    Country                                                                         139 non-null    object
#  1    Business environment_2020                                                       131 non-null    float64
#  2    Business environment_2021                                                       132 non-null    float64
#  3    Business environment_2022                                                       132 non-null    float64
#  4    Business sophistication index_2020                                              131 non-null    float64
#  5    Business sophistication index_2021                                              132 non-null    float64
#  6    Business sophistication index_2022                                              132 non-null    float64
#  7    Citable documents H-index_2020                                                  131 non-null    float64
#  8    Citable documents H-index_2021                                                  132 non-null    float64
#  9    Citable documents H-index_2022                                                  132 non-null    float64
#  10   Creative goods and services_2020                                                131 non-null    float64
#  11   Creative goods and services_2021                                                132 non-null    float64
#  12   Creative goods and services_2022                                                132 non-null    float64
#  13   Creative goods exports, % total trade_2020                                      131 non-null    float64
#  14   Creative goods exports, % total trade_2021                                      132 non-null    float64
#  15   Creative goods exports, % total trade_2022                                      132 non-null    float64
#  16   Creative outputs index_2020                                                     131 non-null    float64
#  17   Creative outputs index_2021                                                     132 non-null    float64
#  18   Creative outputs index_2022                                                     132 non-null    float64
#  19   Cultural and creative services exports, % total trade_2020                      131 non-null    float64
#  20   Cultural and creative services exports, % total trade_2021                      128 non-null    float64
#  21   Cultural and creative services exports, % total trade_2022                      132 non-null    float64
#  22   Domestic market scale, bn PPP$_2020                                             131 non-null    float64
#  23   Domestic market scale, bn PPP$_2021                                             132 non-null    float64
#  24   Domestic market scale, bn PPP$_2022                                             132 non-null    float64
#  25   Ease of getting credit_2020                                                     131 non-null    float64
#  26   Ease of getting credit_2021                                                     132 non-null    float64
#  27   Ease of getting credit_2022                                                     0 non-null      float64
#  28   Ease of starting a business_2020                                                131 non-null    float64
#  29   Ease of starting a business_2021                                                132 non-null    float64
#  30   Ease of starting a business_2022                                                0 non-null      float64
#  31   Ecological sustainability_2020                                                  131 non-null    float64
#  32   Ecological sustainability_2021                                                  132 non-null    float64
#  33   Ecological sustainability_2022                                                  132 non-null    float64
#  34   Expenditure on education, % GDP_2020                                            131 non-null    float64
#  35   Expenditure on education, % GDP_2021                                            130 non-null    float64
#  36   Expenditure on education, % GDP_2022                                            132 non-null    float64
#  37   Firms offering formal training, %_2020                                          131 non-null    float64
#  38   Firms offering formal training, %_2021                                          125 non-null    float64
#  39   Firms offering formal training, %_2022                                          132 non-null    float64
#  40   General infrastructure_2020                                                     131 non-null    float64
#  41   General infrastructure_2021                                                     132 non-null    float64
#  42   General infrastructure_2022                                                     132 non-null    float64
#  43   Global Innovation Index_2020                                                    131 non-null    float64
#  44   Global Innovation Index_2021                                                    132 non-null    float64
#  45   Global Innovation Index_2022                                                    132 non-null    float64
#  46   Government effectiveness_2020                                                   131 non-null    float64
#  47   Government effectiveness_2021                                                   132 non-null    float64
#  48   Government effectiveness_2022                                                   132 non-null    float64
#  49   Government's online service_2020                                                131 non-null    float64
#  50   Government's online service_2021                                                131 non-null    float64
#  51   Government's online service_2022                                                132 non-null    float64
#  52   Graduates in science and engineering, %_2020                                    131 non-null    float64
#  53   Graduates in science and engineering, %_2021                                    130 non-null    float64
#  54   Graduates in science and engineering, %_2022                                    132 non-null    float64
#  55   Gross expenditure on R&D, % GDP_2020                                            0 non-null      float64
#  56   Gross expenditure on R&D, % GDP_2021                                            131 non-null    float64
#  57   Gross expenditure on R&D, % GDP_2022                                            132 non-null    float64
#  58   High-tech exports, % total trade_2020                                           131 non-null    float64
#  59   High-tech exports, % total trade_2021                                           132 non-null    float64
#  60   High-tech exports, % total trade_2022                                           132 non-null    float64
#  61   High-tech imports, % total trade_2020                                           131 non-null    float64
#  62   High-tech imports, % total trade_2021                                           132 non-null    float64
#  63   High-tech imports, % total trade_2022                                           132 non-null    float64
#  64   High-tech manufacturing, %_2020                                                 131 non-null    float64
#  65   High-tech manufacturing, %_2021                                                 131 non-null    float64
#  66   High-tech manufacturing, %_2022                                                 132 non-null    float64
#  67   Human capital and research index_2020                                           131 non-null    float64
#  68   Human capital and research index_2021                                           132 non-null    float64
#  69   Human capital and research index_2022                                           132 non-null    float64
#  70   Information and Communications Technology access_2020                           131 non-null    float64
#  71   Information and Communications Technology access_2021                           132 non-null    float64
#  72   Information and Communications Technology access_2022                           132 non-null    float64
#  73   Information and Communications Technology services exports, % total trade_2020  131 non-null    float64
#  74   Information and Communications Technology services exports, % total trade_2021  132 non-null    float64
#  75   Information and Communications Technology services exports, % total trade_2022  132 non-null    float64
#  76   Information and Communications Technology services imports, % total trade_2020  131 non-null    float64
#  77   Information and Communications Technology services imports, % total trade_2021  132 non-null    float64
#  78   Information and Communications Technology services imports, % total trade_2022  132 non-null    float64
#  79   Information and Communications Technology use_2020                              131 non-null    float64
#  80   Information and Communications Technology use_2021                              132 non-null    float64
#  81   Information and Communications Technology use_2022                              132 non-null    float64
#  82   Infrastructure index_2020                                                       131 non-null    float64
#  83   Infrastructure index_2021                                                       132 non-null    float64
#  84   Infrastructure index_2022                                                       132 non-null    float64
#  85   Intangible assets_2020                                                          131 non-null    float64
#  86   Intangible assets_2021                                                          132 non-null    float64
#  87   Intangible assets_2022                                                          132 non-null    float64
#  88   Joint venture/strategic alliance deals/bn PPP$ GDP_2020                         131 non-null    float64
#  89   Joint venture/strategic alliance deals/bn PPP$ GDP_2021                         131 non-null    float64
#  90   Joint venture/strategic alliance deals/bn PPP$ GDP_2022                         132 non-null    float64
#  91   Knowledge absorption_2020                                                       131 non-null    float64
#  92   Knowledge absorption_2021                                                       132 non-null    float64
#  93   Knowledge absorption_2022                                                       132 non-null    float64
#  94   Knowledge and technology outputs index_2020                                     131 non-null    float64
#  95   Knowledge and technology outputs index_2021                                     132 non-null    float64
#  96   Knowledge and technology outputs index_2022                                     132 non-null    float64
#  97   Knowledge workers_2020                                                          131 non-null    float64
#  98   Knowledge workers_2021                                                          132 non-null    float64
#  99   Knowledge workers_2022                                                          132 non-null    float64
#  100  Knowledge-intensive employment, %_2020                                          131 non-null    float64
#  101  Knowledge-intensive employment, %_2021                                          130 non-null    float64
#  102  Knowledge-intensive employment, %_2022                                          132 non-null    float64
#  103  Logistics performance_2020                                                      131 non-null    float64
#  104  Logistics performance_2021                                                      132 non-null    float64
#  105  Logistics performance_2022                                                      132 non-null    float64
#  106  Market sophistication index_2020                                                131 non-null    float64
#  107  Market sophistication index_2021                                                132 non-null    float64
#  108  Market sophistication index_2022                                                132 non-null    float64
#  109  Mobile app creation/bn PPP$ GDP_2020                                            131 non-null    float64
#  110  Mobile app creation/bn PPP$ GDP_2021                                            129 non-null    float64
#  111  Mobile app creation/bn PPP$ GDP_2022                                            132 non-null    float64
#  112  Online creativity_2020                                                          131 non-null    float64
#  113  Online creativity_2021                                                          132 non-null    float64
#  114  Online creativity_2022                                                          132 non-null    float64
#  115  PISA scales in reading, maths and science_2020                                  131 non-null    float64
#  116  PISA scales in reading, maths and science_2021                                  128 non-null    float64
#  117  PISA scales in reading, maths and science_2022                                  132 non-null    float64
#  118  Political and operational stability_2020                                        131 non-null    float64
#  119  Political and operational stability_2021                                        132 non-null    float64
#  120  Political and operational stability_2022                                        132 non-null    float64
#  121  Political environment_2020                                                      131 non-null    float64
#  122  Political environment_2021                                                      132 non-null    float64
#  123  Political environment_2022                                                      132 non-null    float64
#  124  Pupil-teacher ratio, secondary_2020                                             131 non-null    float64
#  125  Pupil-teacher ratio, secondary_2021                                             131 non-null    float64
#  126  Pupil-teacher ratio, secondary_2022                                             132 non-null    float64
#  127  QS university ranking average score of top 3 universities_2020                  131 non-null    float64
#  128  QS university ranking average score of top 3 universities_2021                  132 non-null    float64
#  129  QS university ranking average score of top 3 universities_2022                  132 non-null    float64
#  130  Research and development (R&D)_2020                                             131 non-null    float64
#  131  Research and development (R&D)_2021                                             132 non-null    float64
#  132  Research and development (R&D)_2022                                             132 non-null    float64
#  133  Scientific and technical articles/bn PPP$ GDP_2020                              131 non-null    float64
#  134  Scientific and technical articles/bn PPP$ GDP_2021                              131 non-null    float64
#  135  Scientific and technical articles/bn PPP$ GDP_2022                              132 non-null    float64
#  136  Software spending, % GDP_2020                                                   131 non-null    float64
#  137  Software spending, % GDP_2021                                                   129 non-null    float64
#  138  Software spending, % GDP_2022                                                   132 non-null    float64
#  139  Tertiary education_2020                                                         131 non-null    float64
#  140  Tertiary education_2021                                                         132 non-null    float64
#  141  Tertiary education_2022                                                         132 non-null    float64
#  142  Tertiary enrolment, % gross_2020                                                131 non-null    float64
#  143  Tertiary enrolment, % gross_2021                                                131 non-null    float64
#  144  Tertiary enrolment, % gross_2022                                                132 non-null    float64
#  145  University-industry R&D collaboration_2020                                      131 non-null    float64
#  146  University-industry R&D collaboration_2021                                      131 non-null    float64
#  147  University-industry R&D collaboration_2022                                      132 non-null    float64
#  148  Region                                                                          139 non-null    object
#  149  Region2                                                                         139 non-null    object
#  150  Euro area                                                                       139 non-null    int64
#  151  European Union                                                                  139 non-null    int64
#  152  OECD members                                                                    139 non-null    int64
#  153  Least developed countries                                                       139 non-null    int64
#  154  Income                                                                          139 non-null    object
#  155  High income                                                                     139 non-null    int64
# dtypes: float64(147), int64(5), object(4)
# memory usage: 169.5+ KB

# %% [markdown]
# # 1. Таблицы сопряжённости<a class="anchor" id="chapter1"></a>

# %% [markdown]
# [Подробнее о построении таблиц сопряженности](https://pbpython.com/pandas-crosstab.html)

# %%
pd.crosstab(df['Income'], df['Region2'])  # ячейки содержат частоты
# Out:
# Region2        Americas  Asia-Pacific  Europe  Middle East and North Africa  \
# Income
# high income           7             7      31                             7
# low income            0             1       1                             0
# middle income        15            19      13                             8
#
# Region2        Sub-Saharan Africa
# Income
# high income                     0
# low income                     13
# middle income                  17

# %%
df.groupby('OECD members')['European Union'].value_counts(normalize=True).unstack()  # ячейки содержат проценты
# Out:
# European Union         0         1
# OECD members
# 0               0.950495  0.049505
# 1               0.421053  0.578947

# %%
pd.crosstab(df['Income'], df['Region2'], margins=True)  # добавлены суммы по строкам и столбцам
# Out:
# Region2        Americas  Asia-Pacific  Europe  Middle East and North Africa  \
# Income
# high income           7             7      31                             7
# low income            0             1       1                             0
# middle income        15            19      13                             8
# All                  22            27      45                            15
#
# Region2        Sub-Saharan Africa  All
# Income
# high income                     0   52
# low income                     13   15
# middle income                  17   72
# All                            30  139

# %%
pd.crosstab(df['Income'], df['Region2'], margins=True, margins_name='Total') #All заменено на Total
# Out:
# Region2        Americas  Asia-Pacific  Europe  Middle East and North Africa  \
# Income
# high income           7             7      31                             7
# low income            0             1       1                             0
# middle income        15            19      13                             8
# Total                22            27      45                            15
#
# Region2        Sub-Saharan Africa  Total
# Income
# high income                     0     52
# low income                     13     15
# middle income                  17     72
# Total                          30    139

# %%
pd.crosstab(df['Income'], df['Region2'], margins=True, margins_name='Total', normalize=True) 
# проценты вместо частот
# Out:
# Region2        Americas  Asia-Pacific    Europe  Middle East and North Africa  \
# Income
# high income    0.050360      0.050360  0.223022                      0.050360
# low income     0.000000      0.007194  0.007194                      0.000000
# middle income  0.107914      0.136691  0.093525                      0.057554
# Total          0.158273      0.194245  0.323741                      0.107914
#
# Region2        Sub-Saharan Africa     Total
# Income
# high income              0.000000  0.374101
# low income               0.093525  0.107914
# middle income            0.122302  0.517986
# Total                    0.215827  1.000000

# %% [markdown]
# Можно сделать вывод, что более половины (52%) стран выборки имеют средний уровень дохода. В Регионе Африки к югу от Сахары находятся 22% стран. Странны Европы с высоким доходом составляют 22% выборки.

# %%
pd.crosstab(df['Income'], df['Region2'], margins=True, margins_name='Total', normalize='columns')
# сумма значений каждого столбца равна 1
# Out:
# Region2        Americas  Asia-Pacific    Europe  Middle East and North Africa  \
# Income
# high income    0.318182      0.259259  0.688889                      0.466667
# low income     0.000000      0.037037  0.022222                      0.000000
# middle income  0.681818      0.703704  0.288889                      0.533333
#
# Region2        Sub-Saharan Africa     Total
# Income
# high income              0.000000  0.374101
# low income               0.433333  0.107914
# middle income            0.566667  0.517986

# %% [markdown]
# Основываясь на данных таблицы выше можно сделать выводы о доле стран с разным уровнем дохода в каждом регионе. В Европе 69% стран относятся к группе с высоким доходом. В Регионе Африки к югу от Сахары 57% стран относятся к группе со средним доходом.

# %%
pd.crosstab(df['Region2'], df['Income'], margins=True, margins_name='Total', normalize='columns')
# поменяли переменные местами
# Out:
# Income                        high income  low income  middle income     Total
# Region2
# Americas                         0.134615    0.000000       0.208333  0.158273
# Asia-Pacific                     0.134615    0.066667       0.263889  0.194245
# Europe                           0.596154    0.066667       0.180556  0.323741
# Middle East and North Africa     0.134615    0.000000       0.111111  0.107914
# Sub-Saharan Africa               0.000000    0.866667       0.236111  0.215827

# %% [markdown]
# На основе этих данных мы можем увидеть долю стран из разных регионов в каждой группе доходов. В группе с высоким доходом 60% стран расположены в Европе. В группе с низким доходом 87% стран расположены в странах Африки к югу от Сахары. В группе со средним доходом 26% стран расположены в Азиатско-Тихоокеанском регионе.

# %%
pd.crosstab(df['Income'], df['Region2'], margins=True, margins_name='Total', normalize='index')
# устанавливаем параметр normalize='index'
# получаем процент по строкам
# Out:
# Region2        Americas  Asia-Pacific    Europe  Middle East and North Africa  \
# Income
# high income    0.134615      0.134615  0.596154                      0.134615
# low income     0.000000      0.066667  0.066667                      0.000000
# middle income  0.208333      0.263889  0.180556                      0.111111
# Total          0.158273      0.194245  0.323741                      0.107914
#
# Region2        Sub-Saharan Africa
# Income
# high income              0.000000
# low income               0.866667
# middle income            0.236111
# Total                    0.215827

# %%
df.groupby('Income')['Region2'].value_counts().unstack().plot(kind='bar')
# столбчатая диаграмма с группировкой
# длина столбцов отражает частоту
# Out:
# <Axes: xlabel='Income'>

# %%
df.groupby('Income')['Region'].value_counts(normalize=True).unstack().plot(kind='bar')
# столбчатая диаграмма с группировкой
# длина столбцов отражает процент
# Out:
# <Axes: xlabel='Income'>

# %%
df.groupby('Region2')['Income'].value_counts().unstack().plot(kind='bar')
# группирующая и основная переменная заменены местами
# длина столбцов отражает частоту
# Out:
# <Axes: xlabel='Region2'>

# %%
df.groupby('Region2')['Income'].value_counts(normalize=True).unstack().plot(kind='bar')
# длина столбцов отражает процент
# Out:
# <Axes: xlabel='Region2'>

# %% [markdown]
# # 2. Статистический тест Хи-квадрат<a class="anchor" id="chapter2"></a>

# %% [markdown]
# **Членство в Европейском союзе и участие в ОЭСР**

# %%
ct_income_oecd = pd.crosstab(df['European Union'], df['OECD members'])
ct_income_oecd
# сохраним таблицу сопряжённости в переменную
# Out:
# OECD members     0   1
# European Union
# 0               96  16
# 1                5  22

# %%
stats.chi2_contingency(ct_income_oecd)
# Out:
# Chi2ContingencyResult(statistic=46.12616772524684, pvalue=1.1087758976426808e-11, dof=1, expected_freq=array([[81.38129496, 30.61870504],
#        [19.61870504,  7.38129496]]))

# %% [markdown]
# chi2 = 46.12616772524684
#
# p-value = 1.1087758976426808e-11 (это очень маленькое число)
#
# [Подробнее про экспоненциальную запись](https://ru.ruwiki.ru/wiki/%D0%AD%D0%BA%D1%81%D0%BF%D0%BE%D0%BD%D0%B5%D0%BD%D1%86%D0%B8%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D0%B7%D0%B0%D0%BF%D0%B8%D1%81%D1%8C)
#
# array - содержит ожидаемые частоты (для применения теста Хи-квадрт не более 5% ячеек должы содержать ожидаемую частоту меньше 5)
#
# В нашей таблице нет ожидаемых частот менее 5, значит тест Хи-квадрат применим.

# %%
print('chi2 = ', stats.chi2_contingency(ct_income_oecd)[0], '   p-value =', stats.chi2_contingency(ct_income_oecd)[1])
# Out:
# chi2 =  46.12616772524684    p-value = 1.1087758976426808e-11

# %% [markdown]
# ## Выводы

# %% [markdown]
# H0: отсутствует взаимосвязь между членством в Европейском союзе и участием в ОЭСР
#
# H1: существует взаимосвязь между членством в Европейском союзе и участием в ОЭСР
#
# p-value < 0.05 (стандартный уровень значимости - 5%)
#
# p-value < 0.01
#
# Гипотеза H1 принимается на уровне значимости 1%.

# %% [markdown]
# **Показатель "Business environment_2022" и регион расположения страны**

# %%
ct_be_region = pd.crosstab(df['Business environment_2022'], df['Region'])
ct_be_region
# Out:
# Region                     East Asia & Pacific  Europe & Central Asia  \
# Business environment_2022
# 0.0                                          0                      0
# 0.8                                          0                      1
# 13.3                                         0                      0
# 14.5                                         0                      0
# 17.9                                         0                      1
# ...                                        ...                    ...
# 82.1                                         1                      0
# 85.8                                         0                      1
# 86.8                                         0                      1
# 89.0                                         1                      0
# 89.4                                         0                      0
#
# Region                     Latin America & Caribbean  \
# Business environment_2022
# 0.0                                                0
# 0.8                                                0
# 13.3                                               0
# 14.5                                               1
# 17.9                                               0
# ...                                              ...
# 82.1                                               0
# 85.8                                               0
# 86.8                                               0
# 89.0                                               0
# 89.4                                               0
#
# Region                     Middle East & North Africa  North America  \
# Business environment_2022
# 0.0                                                 1              0
# 0.8                                                 0              0
# 13.3                                                1              0
# 14.5                                                0              0
# 17.9                                                0              0
# ...                                               ...            ...
# 82.1                                                0              0
# 85.8                                                0              0
# 86.8                                                0              0
# 89.0                                                0              0
# 89.4                                                1              0
#
# Region                     South Asia  Sub-Saharan Africa
# Business environment_2022
# 0.0                                 0                   1
# 0.8                                 0                   0
# 13.3                                0                   0
# 14.5                                0                   0
# 17.9                                0                   0
# ...                               ...                 ...
# 82.1                                0                   0
# 85.8                                0                   0
# 86.8                                0                   0
# 89.0                                0                   0
# 89.4                                0                   0
#
# [118 rows x 7 columns]

# %%
stats.chi2_contingency(ct_be_region)
# Out:
# Chi2ContingencyResult(statistic=729.1177756918371, pvalue=0.23197988655562385, dof=702, expected_freq=array([[0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.25757576, 0.71212121, 0.27272727, 0.24242424, 0.03030303,
#         0.07575758, 0.40909091],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545],
#        [0.12878788, 0.35606061, 0.13636364, 0.12121212, 0.01515152,
#         0.03787879, 0.20454545]]))

# %% [markdown]
# Обратите внимание, что статистический тест Хи-квадрат в данном случае не применим. У нас недостаточно частот в каждой ячейке таблицы сопряженности, чтобы сделать выводы о взаимосвязи между переменными. В данном случае нужно применить другой статистический тест для оценки взаимосвязи.

# %% [markdown]
# # 3. Тесты на нормальность<a class="anchor" id="chapter3"></a>

# %% [markdown]
# ## Тест на нормальность Шапиро-Вилка

# %% [markdown]
# Проверим на нормальность переменную **Information and Communications Technology services exports, % total trade_2022**

# %%
stats.shapiro(df['Information and Communications Technology services exports, % total trade_2022'].dropna())
# Out:
# ShapiroResult(statistic=0.7589935871648649, pvalue=1.91792579784507e-13)

# %% [markdown]
# H0: Распределение значений переменной "Экспорт услуг в сфере информационно-коммуникационных технологий, % от общего объема" статистически значимо не отличается от нормального распределения.
#
# H1: Распределение значений переменной "Экспорт услуг в сфере информационно-коммуникационных технологий, % от общего объема" статистически значимо отличается от нормального распределения.
#
# Вывод: поскольку p-vale < 0.05, гипотеза H1 принимается => распределение статистически значимо отличается от нормального

# %%
sns.distplot(df['Information and Communications Technology services exports, % total trade_2022'].dropna(), fit=norm)
# Out:
# <Axes: xlabel='Information and Communications Technology services exports, % total trade_2022', ylabel='Density'>

# %% [markdown]
# В дополнение к построению графика распределения переменной, мы можем использовать график квантиль-квантиль (Q-Q) для оценки отклонения исходных данных от теоретического (нормального, в данном случае) распределения.

# %%
pg.qqplot(df['Information and Communications Technology services exports, % total trade_2022'], dist = 'norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# На графике видно, что квантили в наших данных заметно отличаются от квантилей нормального распределения. R^2 — это коэффициент детерминации, который измеряет качество соответствия линейной модели — красной линии — нашим данным и, следовательно, оценивает, насколько хорошо данное отношение может быть аппроксимировано линейной функцией. Чем лучше линейная модель соответствует данным, тем более похожи два распределения. В данном случае график показывает, что эмпирическое распределение далеко от нормального. Это дополнительно подтверждается гистограммой и статистическим тестом выше.

# %% [markdown]
# ### ! Но для выборки размером более 50 целесообразно применить тест на нормальность Колмогорова-Смирнова.

# %% [markdown]
# ## Тест на нормальность Колмогорова-Смирнова

# %% [markdown]
# Проверим на номальность переменную **University-industry R&D collaboration_2022**

# %%
stats.kstest(df['University-industry R&D collaboration_2022'].dropna(), 'norm', args=(df['University-industry R&D collaboration_2022'].dropna().mean(), df['University-industry R&D collaboration_2022'].dropna().std()))
# Out:
# KstestResult(statistic=0.06285755871505036, pvalue=0.6505715098926618, statistic_location=29.0, statistic_sign=-1)

# %% [markdown]
# H0: Распределение значений переменной "Сотрудничество университетов и промышленности в области НИОКР" статистически значимо не отличается от нормального распределения.
#
# H1: Распределение значений переменной "Сотрудничество университетов и промышленности в области НИОКР" статистически значимо отличается от нормального распределения.
#
# Вывод: поскольку p-value > 0.05, гипотеза H1 отвергается, а H0 не отвергается => распределение статистически значимо не отличается от нормального

# %%
sns.distplot(df['University-industry R&D collaboration_2022'].dropna(), fit=norm)
# Out:
# <Axes: xlabel='University-industry R&D collaboration_2022', ylabel='Density'>

# %%
pg.qqplot(df['University-industry R&D collaboration_2022'], dist = 'norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# Проверим на номальность переменную **Information and Communications Technology use_2022**

# %%
stats.kstest(df['Information and Communications Technology use_2022'].dropna(), 'norm', args=(df['Information and Communications Technology use_2022'].dropna().mean(), df['Information and Communications Technology use_2022'].dropna().std()))
# распределение отличается от нормального
# Out:
# KstestResult(statistic=0.13715514990599909, pvalue=0.01255647340989818, statistic_location=71.0, statistic_sign=-1)

# %%
sns.distplot(df['Information and Communications Technology use_2022'].dropna(), fit=norm)
# Out:
# <Axes: xlabel='Information and Communications Technology use_2022', ylabel='Density'>

# %%
pg.qqplot(df['Information and Communications Technology use_2022'], dist = 'norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# Проверим на нормальность переменную **High-tech manufacturing, %_2022**

# %%
stats.kstest(df['High-tech manufacturing, %_2022'].dropna(), 'norm', args=(df['High-tech manufacturing, %_2022'].dropna().mean(), df['High-tech manufacturing, %_2022'].dropna().std()))
# распределение отличается от нормального
# Out:
# KstestResult(statistic=0.1286546983117936, pvalue=0.02301697134158888, statistic_location=0.0, statistic_sign=-1)

# %%
sns.distplot(df['High-tech manufacturing, %_2022'].dropna(), fit=norm)
# Out:
# <Axes: xlabel='High-tech manufacturing, %_2022', ylabel='Density'>

# %%
pg.qqplot(df['High-tech manufacturing, %_2022'], dist = 'norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# Проверим на нормальность переменную **Government effectiveness_2022**

# %%
stats.kstest(df['Government effectiveness_2022'].dropna(), 'norm', args=(df['Government effectiveness_2022'].dropna().mean(), df['Government effectiveness_2022'].dropna().std()))
# распределение не отличается от нормального
# Out:
# KstestResult(statistic=0.0793056239165289, pvalue=0.35864047824821477, statistic_location=53.0, statistic_sign=1)

# %%
sns.distplot(df['Government effectiveness_2022'].dropna(), fit=norm)
# Out:
# <Axes: xlabel='Government effectiveness_2022', ylabel='Density'>

# %%
pg.qqplot(df['Government effectiveness_2022'], dist = 'norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# Проверим на нормальность переменную **Business environment_2022**

# %%
stats.kstest(df['Business environment_2022'].dropna(), 'norm', args=(df['Business environment_2022'].dropna().mean(), df['Business environment_2022'].dropna().std()))
# распределение не отличается от нормального
# Out:
# KstestResult(statistic=0.042580660762039146, pvalue=0.9621605872389752, statistic_location=56.7, statistic_sign=1)

# %%
sns.distplot(df['Business environment_2022'].dropna(), fit=norm)
# Out:
# <Axes: xlabel='Business environment_2022', ylabel='Density'>

# %%
pg.qqplot(df['Business environment_2022'], dist = 'norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# Проверим на нормальность переменную **Creative goods and services_2022**

# %%
stats.kstest(df['Creative goods and services_2022'].dropna(), 'norm', args=(df['Creative goods and services_2022'].dropna().mean(), df['Creative goods and services_2022'].dropna().std()))
# распределение не отличается от нормального
# Out:
# KstestResult(statistic=0.1059332353284872, pvalue=0.09606350812447681, statistic_location=7.9, statistic_sign=1)

# %% [markdown]
# Мы проанализировали распределение значений нескольких переменных. Четыре из них имеют распределения, которые статистически значимо не отличаются от нормального распределения, остальные переменные имеют распределения, которые статистически значимо отличаются от нормального распределения.

# %% [markdown]
# # 4. Корреляционный анализ<a class="anchor" id="chapter4"></a>

# %% [markdown]
# ### Коэффициент корреляции Пирсона

# %% [markdown]
# Рассчитываются коэффициенты корреляции Пирсона между всеми возможными парами числовых переменных. Это плохое решение, потому что для расчета взаимосвязи между определенными парами переменных датасета этот коэффициент не подходит.
#
# По диагонали матрицы всегда 1, это корреляция переменной с самой собой.

# %%
df.corr(numeric_only=True)
# Out:
#                                     Business environment_2020  \
# Business environment_2020                            1.000000
# Business environment_2021                            1.000000
# Business environment_2022                            0.374400
# Business sophistication index_2020                   0.645183
# Business sophistication index_2021                   0.652948
# ...                                                       ...
# Euro area                                            0.346680
# European Union                                       0.401291
# OECD members                                         0.594219
# Least developed countries                           -0.394077
# High income                                          0.565094
#
#                                     Business environment_2021  \
# Business environment_2020                            1.000000
# Business environment_2021                            1.000000
# Business environment_2022                            0.381639
# Business sophistication index_2020                   0.645183
# Business sophistication index_2021                   0.656416
# ...                                                       ...
# Euro area                                            0.346186
# European Union                                       0.400942
# OECD members                                         0.591192
# Least developed countries                           -0.419708
# High income                                          0.565326
#
#                                     Business environment_2022  \
# Business environment_2020                            0.374400
# Business environment_2021                            0.381639
# Business environment_2022                            1.000000
# Business sophistication index_2020                   0.500275
# Business sophistication index_2021                   0.502070
# ...                                                       ...
# Euro area                                            0.153601
# European Union                                       0.104429
# OECD members                                         0.315914
# Least developed countries                           -0.198400
# High income                                          0.420853
#
#                                     Business sophistication index_2020  \
# Business environment_2020                                     0.645183
# Business environment_2021                                     0.645183
# Business environment_2022                                     0.500275
# Business sophistication index_2020                            1.000000
# Business sophistication index_2021                            0.990146
# ...                                                                ...
# Euro area                                                     0.406886
# European Union                                                0.486120
# OECD members                                                  0.688329
# Least developed countries                                    -0.376083
# High income                                                   0.677409
#
#                                     Business sophistication index_2021  \
# Business environment_2020                                     0.652948
# Business environment_2021                                     0.656416
# Business environment_2022                                     0.502070
# Business sophistication index_2020                            0.990146
# Business sophistication index_2021                            1.000000
# ...                                                                ...
# Euro area                                                     0.422518
# European Union                                                0.496682
# OECD members                                                  0.697299
# Least developed countries                                    -0.411743
# High income                                                   0.666980
#
#                                     Business sophistication index_2022  \
# Business environment_2020                                     0.686277
# Business environment_2021                                     0.690642
# Business environment_2022                                     0.523083
# Business sophistication index_2020                            0.976785
# Business sophistication index_2021                            0.983350
# ...                                                                ...
# Euro area                                                     0.449959
# European Union                                                0.528001
# OECD members                                                  0.710892
# Least developed countries                                    -0.460060
# High income                                                   0.708961
#
#                                     Citable documents H-index_2020  \
# Business environment_2020                                 0.613813
# Business environment_2021                                 0.613813
# Business environment_2022                                 0.360508
# Business sophistication index_2020                        0.764934
# Business sophistication index_2021                        0.767656
# ...                                                            ...
# Euro area                                                 0.306666
# European Union                                            0.355093
# OECD members                                              0.687717
# Least developed countries                                -0.294624
# High income                                               0.574289
#
#                                     Citable documents H-index_2021  \
# Business environment_2020                                 0.613944
# Business environment_2021                                 0.614306
# Business environment_2022                                 0.368032
# Business sophistication index_2020                        0.766761
# Business sophistication index_2021                        0.770736
# ...                                                            ...
# Euro area                                                 0.307489
# European Union                                            0.356811
# OECD members                                              0.688251
# Least developed countries                                -0.306719
# High income                                               0.577964
#
#                                     Citable documents H-index_2022  \
# Business environment_2020                                 0.606913
# Business environment_2021                                 0.607441
# Business environment_2022                                 0.376547
# Business sophistication index_2020                        0.765421
# Business sophistication index_2021                        0.769207
# ...                                                            ...
# Euro area                                                 0.307628
# European Union                                            0.356881
# OECD members                                              0.684447
# Least developed countries                                -0.328444
# High income                                               0.579056
#
#                                     Creative goods and services_2020  ...  \
# Business environment_2020                                   0.472930  ...
# Business environment_2021                                   0.472930  ...
# Business environment_2022                                   0.463312  ...
# Business sophistication index_2020                          0.728315  ...
# Business sophistication index_2021                          0.737732  ...
# ...                                                              ...  ...
# Euro area                                                   0.337721  ...
# European Union                                              0.423584  ...
# OECD members                                                0.553040  ...
# Least developed countries                                  -0.372494  ...
# High income                                                 0.558997  ...
#
#                                     Tertiary enrolment, % gross_2021  \
# Business environment_2020                                   0.577426
# Business environment_2021                                   0.583946
# Business environment_2022                                   0.241300
# Business sophistication index_2020                          0.596799
# Business sophistication index_2021                          0.615734
# ...                                                              ...
# Euro area                                                   0.413153
# European Union                                              0.450987
# OECD members                                                0.598500
# Least developed countries                                  -0.553622
# High income                                                 0.598649
#
#                                     Tertiary enrolment, % gross_2022  \
# Business environment_2020                                   0.543785
# Business environment_2021                                   0.551974
# Business environment_2022                                   0.273803
# Business sophistication index_2020                          0.556469
# Business sophistication index_2021                          0.578060
# ...                                                              ...
# Euro area                                                   0.410609
# European Union                                              0.450607
# OECD members                                                0.568779
# Least developed countries                                  -0.558450
# High income                                                 0.585176
#
#                                     University-industry R&D collaboration_2020  \
# Business environment_2020                                             0.485420
# Business environment_2021                                             0.485420
# Business environment_2022                                             0.648155
# Business sophistication index_2020                                    0.747689
# Business sophistication index_2021                                    0.732183
# ...                                                                        ...
# Euro area                                                             0.259445
# European Union                                                        0.289466
# OECD members                                                          0.517930
# Least developed countries                                            -0.320976
# High income                                                           0.538649
#
#                                     University-industry R&D collaboration_2021  \
# Business environment_2020                                             0.498880
# Business environment_2021                                             0.514098
# Business environment_2022                                             0.685761
# Business sophistication index_2020                                    0.745958
# Business sophistication index_2021                                    0.742292
# ...                                                                        ...
# Euro area                                                             0.267817
# European Union                                                        0.297090
# OECD members                                                          0.531768
# Least developed countries                                            -0.338004
# High income                                                           0.550066
#
#                                     University-industry R&D collaboration_2022  \
# Business environment_2020                                             0.516637
# Business environment_2021                                             0.532889
# Business environment_2022                                             0.759305
# Business sophistication index_2020                                    0.719563
# Business sophistication index_2021                                    0.716682
# ...                                                                        ...
# Euro area                                                             0.236539
# European Union                                                        0.274629
# OECD members                                                          0.498992
# Least developed countries                                            -0.344103
# High income                                                           0.527546
#
#                                     Euro area  European Union  OECD members  \
# Business environment_2020            0.346680        0.401291      0.594219
# Business environment_2021            0.346186        0.400942      0.591192
# Business environment_2022            0.153601        0.104429      0.315914
# Business sophistication index_2020   0.406886        0.486120      0.688329
# Business sophistication index_2021   0.422518        0.496682      0.697299
# ...                                       ...             ...           ...
# Euro area                            1.000000        0.834966      0.530387
# European Union                       0.834966        1.000000      0.596459
# OECD members                         0.530387        0.596459      1.000000
# Least developed countries           -0.196648       -0.235516     -0.294224
# High income                          0.530273        0.597503      0.659962
#
#                                     Least developed countries  High income
# Business environment_2020                           -0.394077     0.565094
# Business environment_2021                           -0.419708     0.565326
# Business environment_2022                           -0.198400     0.420853
# Business sophistication index_2020                  -0.376083     0.677409
# Business sophistication index_2021                  -0.411743     0.666980
# ...                                                       ...          ...
# Euro area                                           -0.196648     0.530273
# European Union                                      -0.235516     0.597503
# OECD members                                        -0.294224     0.659962
# Least developed countries                            1.000000    -0.370842
# High income                                         -0.370842     1.000000
#
# [152 rows x 152 columns]

# %% [markdown]
# Коэффициент корреляции Пирсона можно рассчитать для оценки взаимосвязи между метрическими переменными, распределения значений которых статистически значимо не отличаются от нормального.

# %%
df['University-industry R&D collaboration_2022'].corr(df['Government effectiveness_2022'])
# Out:
# 0.7354650445262583

# %% [markdown]
# Наблюдается сильная положительная корреляция между переменными.

# %%
df.plot('University-industry R&D collaboration_2022', 'Government effectiveness_2022', kind='scatter')
# Out:
# <Axes: xlabel='University-industry R&D collaboration_2022', ylabel='Government effectiveness_2022'>

# %%
df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022']].corrwith(df['University-industry R&D collaboration_2022'])
# коэффициенты корреляции Персона между переменной University-industry R&D collaboration_2022 и 3-мя другими 
# все переменные имеют распределение, близкое к нормальному
# Out:
# Creative goods and services_2022    0.544774
# Business environment_2022           0.759305
# Government effectiveness_2022       0.735465
# dtype: float64

# %%
df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022']].corrwith(df['University-industry R&D collaboration_2022']).sort_values()
# коэффиценты корреляции отсортированы по возрастанию
# Out:
# Creative goods and services_2022    0.544774
# Government effectiveness_2022       0.735465
# Business environment_2022           0.759305
# dtype: float64

# %%
df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']].corr()
# корреляционная матрица на основе 4 переменных
# Out:
#                                             Creative goods and services_2022  \
# Creative goods and services_2022                                    1.000000
# Business environment_2022                                           0.400947
# Government effectiveness_2022                                       0.687971
# University-industry R&D collaboration_2022                          0.544774
#
#                                             Business environment_2022  \
# Creative goods and services_2022                             0.400947
# Business environment_2022                                    1.000000
# Government effectiveness_2022                                0.674534
# University-industry R&D collaboration_2022                   0.759305
#
#                                             Government effectiveness_2022  \
# Creative goods and services_2022                                 0.687971
# Business environment_2022                                        0.674534
# Government effectiveness_2022                                    1.000000
# University-industry R&D collaboration_2022                       0.735465
#
#                                             University-industry R&D collaboration_2022
# Creative goods and services_2022                                              0.544774
# Business environment_2022                                                     0.759305
# Government effectiveness_2022                                                 0.735465
# University-industry R&D collaboration_2022                                    1.000000

# %%
sns.pairplot(df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']]) 
# матрица диаграмм рассеяния

# %%
df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']].corr().stack()
# содержимое корреляционной матрицы представлено как одномерный ряд
# Out:
# Creative goods and services_2022            Creative goods and services_2022              1.000000
#                                             Business environment_2022                     0.400947
#                                             Government effectiveness_2022                 0.687971
#                                             University-industry R&D collaboration_2022    0.544774
# Business environment_2022                   Creative goods and services_2022              0.400947
#                                             Business environment_2022                     1.000000
#                                             Government effectiveness_2022                 0.674534
#                                             University-industry R&D collaboration_2022    0.759305
# Government effectiveness_2022               Creative goods and services_2022              0.687971
#                                             Business environment_2022                     0.674534
#                                             Government effectiveness_2022                 1.000000
#                                             University-industry R&D collaboration_2022    0.735465
# University-industry R&D collaboration_2022  Creative goods and services_2022              0.544774
#                                             Business environment_2022                     0.759305
#                                             Government effectiveness_2022                 0.735465
#                                             University-industry R&D collaboration_2022    1.000000
# dtype: float64

# %%
df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']].corr().stack().sort_values()
# результаты отсортированы
# Out:
# Creative goods and services_2022            Business environment_2022                     0.400947
# Business environment_2022                   Creative goods and services_2022              0.400947
# Creative goods and services_2022            University-industry R&D collaboration_2022    0.544774
# University-industry R&D collaboration_2022  Creative goods and services_2022              0.544774
# Business environment_2022                   Government effectiveness_2022                 0.674534
# Government effectiveness_2022               Business environment_2022                     0.674534
# Creative goods and services_2022            Government effectiveness_2022                 0.687971
# Government effectiveness_2022               Creative goods and services_2022              0.687971
#                                             University-industry R&D collaboration_2022    0.735465
# University-industry R&D collaboration_2022  Government effectiveness_2022                 0.735465
# Business environment_2022                   University-industry R&D collaboration_2022    0.759305
# University-industry R&D collaboration_2022  Business environment_2022                     0.759305
# Creative goods and services_2022            Creative goods and services_2022              1.000000
# Business environment_2022                   Business environment_2022                     1.000000
# Government effectiveness_2022               Government effectiveness_2022                 1.000000
# University-industry R&D collaboration_2022  University-industry R&D collaboration_2022    1.000000
# dtype: float64

# %% [markdown]
# ### Статистическая значимость коэффициента корреляции Пирсона

# %%
stats.pearsonr(df['University-industry R&D collaboration_2022'].dropna(), df['Business environment_2022'].dropna())
# Out:
# PearsonRResult(statistic=0.7593053875329312, pvalue=5.056226771673954e-26)

# %%
print("Pearson's r:", stats.pearsonr(df['University-industry R&D collaboration_2022'].dropna(), df['Business environment_2022'].dropna())[0], 
       '    p-value:', stats.pearsonr(df['University-industry R&D collaboration_2022'].dropna(), df['Business environment_2022'].dropna())[1])
# Out:
# Pearson's r: 0.7593053875329312     p-value: 5.056226771673954e-26

# %% [markdown]
# Переменные **University-industry R&D collaboration** и **Business environment** являются метрическими; распределения их значений не отличаются от нормального. Поэтому для оценки взаимосвязи между ними мы можем рассчитать коэффициент корреляции Пирсона.
#
# H0: нет взаимосвязи между сотрудничеством университетов и промышленности в области НИОКР и бизнес-средой (r = 0)
#
# H1: существует взаимосвязь связь между сотрудничеством университетов и промышленности в области НИОКР и бизнес-средой в 2022 году (r != 0)
#
# 1. Статистическая значимость взаимосвязи: поскольку p-value < 0.05, гипотеза H1 подтвердилась.
# 2. Направление взаимосвязи: коэффициент корреляции положительный, следовательно, между переменными наблюдается прямая взаимосвязь.
# 3. Сила взаимосвязи: коэффициент корреляции равен 0.76, следовательно, между переменными наблюдается сильная корреляция.
#
# Можно сделать вывод, что благоприятная бизнес-среда способствует развитию сотрудничества между университетами и индустрии в области научных исследований.

# %%
sns.regplot(df, x = 'University-industry R&D collaboration_2022', y = 'Business environment_2022').set_title('Pearson correlation')
# Out:
# Text(0.5, 1.0, 'Pearson correlation')

# %% [markdown]
# ### Коэффициент корреляции Спирмена и его статистическая значимость

# %%
df1 = df.dropna(subset=['Information and Communications Technology use_2022', 'High-tech manufacturing, %_2022'])
# удаление наблюдений, содержащих пропуски хотя бы по одной из анализируемых переменных
stats.spearmanr(df1['Information and Communications Technology use_2022'], df1['High-tech manufacturing, %_2022'])
# Out:
# SignificanceResult(statistic=0.6749691181222638, pvalue=7.023352609224242e-19)

# %% [markdown]
# Переменные **Information and Communications Technology use** и **High-tech manufacturing, %** являются метрическими, но их распределения отличаются от нормального. Поэтому для оценки взаимосвязи между ними лучше рассчитать коэффициенты ранговой корреляции (Спирмена или Кендалла). Поскольку значения каждой переменной в основном уникальны, и когда мы проранжируем страны по ним, мы не получим или получим небольшое количество связанных рангов, коэффициент корреляции Спирмена является предпочтительным.
#
# H0: нет взаимосвязи между использованием информационно-коммуникационных технологий и высокотехнологичным производством в 2022 году (r = 0)
#
# H1: существует взаимосвязь между использованием информационно-коммуникационных технологий и высокотехнологичным производством в 2022 году (r != 0)
#
# 1. Статистическая значимость взаимосвязи: поскольку p-value < 0.05, гипотеза H1 подтвердилась.
# 2. Направление взаимосвязи: коэффициент корреляции положительный, следовательно, между переменными наблюдается прямая взаимосвязь.
# 3. Сила взаимосвязи: коэффициент корреляции равен 0.67, следовательно, между переменными наблюдается средняя корреляция.

# %%
df[['Information and Communications Technology use_2022','High-tech manufacturing, %_2022','University-industry R&D collaboration_2022']].corr('spearman') 
# матрица коэффициентов корреляции Спирмена
# Out:
#                                                     Information and Communications Technology use_2022  \
# Information and Communications Technology use_2022                                           1.000000
# High-tech manufacturing, %_2022                                                              0.674969
# University-industry R&D collaboration_2022                                                   0.616121
#
#                                                     High-tech manufacturing, %_2022  \
# Information and Communications Technology use_2022                         0.674969
# High-tech manufacturing, %_2022                                            1.000000
# University-industry R&D collaboration_2022                                 0.544839
#
#                                                     University-industry R&D collaboration_2022
# Information and Communications Technology use_2022                                    0.616121
# High-tech manufacturing, %_2022                                                       0.544839
# University-industry R&D collaboration_2022                                            1.000000

# %%
sns.regplot(data = df1, x = 'Information and Communications Technology use_2022', y = 'High-tech manufacturing, %_2022')
# Out:
# <Axes: xlabel='Information and Communications Technology use_2022', ylabel='High-tech manufacturing, %_2022'>

# %% [markdown]
# ### Коэффициент корреляции Кендалла и его статистическая значимость

# %%
df = pd.read_excel('WIPO-GII.xlsx')
df['Income'].value_counts()
# Out:
# middle income    72
# high income      52
# low income       15
# Name: Income, dtype: int64

# %%
df['Income']=df['Income'].replace('low income', 1)
df['Income']=df['Income'].replace('middle income', 2)
df['Income']=df['Income'].replace('high income', 3)
df['Income'].value_counts()
# перекодирование переменной из текстовой в числовую
# Out:
# 2    72
# 3    52
# 1    15
# Name: Income, dtype: int64

# %%
df1 = df.dropna(subset=['Income', 'University-industry R&D collaboration_2022'])
# удаление наблюдений, содержащих пропуски хотя бы по одной из анализируемых переменных
stats.kendalltau(df1.Income, df1['University-industry R&D collaboration_2022'])
# Out:
# SignificanceResult(statistic=0.43833419909418553, pvalue=2.4846308818292997e-10)

# %% [markdown]
# Переменная **University-industry R&D collaboration_2022** — это метрическая переменная, распределение ее значений отличается от нормального. **Income** — это категориальная переменная с порядковой шкалой измерения. Поэтому для оценки взаимосвязи между ними лучше рассчитать коэффициенты ранговой корреляции (Спирмена или Кендалла). Поскольку большинство значений переменной Income не являются уникальными, при ранжировании стран по этой переменной, получится много связанных рангов, коэффициент корреляции Кендалла является предпочтительным.
#
# H0: нет взаимосвязи между доходом стран и сотрудничеством университетов и промышленности в области НИОКР в 2022 году (r = 0)
#
# H1: существует взаимосвязь между доходом стран и сотрудничеством университетов и промышленности в области НИОКР в 2022 году (r != 0)
#
# 1. Статистическая значимость взаимосвязи: поскольку p-value < 0.05, гипотеза H1 подтвердилась.
# 2. Направление взаимосвязи: коэффициент корреляции положительный, следовательно, между переменными наблюдается прямая взаимосвязь.
# 3. Сила взаимосвязи: коэффициент корреляции равен 0.44, следовательно, между переменными наблюдается слабая корреляция.

# %%
df[['Income','University-industry R&D collaboration_2022','Information and Communications Technology use_2022']].corr('kendall') 
# матрица коэффициентов корреляции Кендалла
# Out:
#                                                       Income  \
# Income                                              1.000000
# University-industry R&D collaboration_2022          0.438334
# Information and Communications Technology use_2022  0.717396
#
#                                                     University-industry R&D collaboration_2022  \
# Income                                                                                0.438334
# University-industry R&D collaboration_2022                                            1.000000
# Information and Communications Technology use_2022                                    0.437374
#
#                                                     Information and Communications Technology use_2022
# Income                                                                                       0.717396
# University-industry R&D collaboration_2022                                                   0.437374
# Information and Communications Technology use_2022                                           1.000000

# %% [markdown]
# ### Точечно-бисериальная корреляция

# %%
df = pd.read_excel('WIPO-GII.xlsx')

# %%
df_clean = df.dropna(subset=['University-industry R&D collaboration_2022', 'High income'])
pb, pval = pointbiserialr(df_clean['University-industry R&D collaboration_2022'], df_clean['High income'])
print(f'Point-biserial correlation: {np.round(pb, 4)}, pvalue = {np.round(pval, 4)}')
# наблюдается статистически значимая средняя корреляция
# Out:
# Point-biserial correlation: 0.5275, pvalue = 0.0

# %%
sns.regplot(data = df_clean, x = 'High income', y = 'University-industry R&D collaboration_2022').set_title('Point-biserial correlation')
# Out:
# Text(0.5, 1.0, 'Point-biserial correlation')

# %% [markdown]
# ### Коэффициент Фи

# %% [markdown]
# Подходит для оценки взаимосвязи связи между двумя бинарными переменными.

# %%
def phi_corrrelation(data: pd.DataFrame, x: str, y: str):
    chi = pd.crosstab(index=data[x], 
                           columns=data[y], margins = True).values
    phi = (chi[0, 0] * chi[1, 1] - chi[1, 0] * chi[0, 1]) / np.sqrt(chi[1, 2] * chi[2, 1] * chi[2, 0] * chi[0, 2])
    return phi

# %%
phi_corrrelation(df, 'High income', 'Least developed countries')
# наблюдается обратная слабая корреляция
# Out:
# -0.3708424979352351

# %% [markdown]
# # 5. Частная корреляция<a class="anchor" id="chapter5"></a>

# %% [markdown]
# Рассчитаем парный коэффициент корреляции между сотрудничеством университетов и промышленности в сфере НИОКР и бизнес-средой в 2022 году.

# %%
stats.pearsonr(df['University-industry R&D collaboration_2022'].dropna(), df['Business environment_2022'].dropna())
# Out:
# PearsonRResult(statistic=0.7593053875329312, pvalue=5.056226771673954e-26)

# %% [markdown]
# Теперь проконтролируем влияние на эту корреляцию переменной **High-tech manufacturing, %_2022**

# %%
df = df.dropna(subset=['High-tech manufacturing, %_2022', 'University-industry R&D collaboration_2022', 'Business environment_2022'])
r_xy = stats.pearsonr(df['University-industry R&D collaboration_2022'], df['Business environment_2022'])[0]
r_xz = stats.pearsonr(df['University-industry R&D collaboration_2022'], df['High-tech manufacturing, %_2022'])[0]
r_yz = stats.pearsonr(df['Business environment_2022'], df['High-tech manufacturing, %_2022'])[0]
r_xy_z = (r_xy - r_xz * r_yz) / sqrt((1 - r_xz ** 2) * (1 - r_yz ** 2))
print('Парный коэффициент корреляции между  University-industry R&D collaboration и Business environment в 2022: ',r_xy)
print('Частный коэффициент корреляции между  University-industry R&D collaboration и Business environment в 2022, с исключением влияния High-tech manufacturing: ',r_xy_z)
# Out:
# Парный коэффициент корреляции между  University-industry R&D collaboration и Business environment в 2022:  0.7593053875329312
# Частный коэффициент корреляции между  University-industry R&D collaboration и Business environment в 2022, с исключением влияния High-tech manufacturing:  0.7454224834023446

# %%
pg.partial_corr(data=df, x='University-industry R&D collaboration_2022', y='Business environment_2022', covar='High-tech manufacturing, %_2022')
# такой же результат с помощью библиотеки pingouin
# Out:
#            n         r         CI95%         p-val
# pearson  132  0.745422  [0.66, 0.81]  1.773242e-24

# %%
pg.partial_corr(data=df, x='Business environment_2022', y='University-industry R&D collaboration_2022', covar='High-tech manufacturing, %_2022', method = 'spearman')
# Out:
#             n         r        CI95%         p-val
# spearman  132  0.702864  [0.6, 0.78]  8.172177e-21

# %% [markdown]
# Можно сделать вывод, что корреляция между сотрудничеством университетов и промышленности в области НИОКР и бизнес-средой существенно не изменилась после того, как мы исключили влияние на их корреляцию переменной, характеризующей высокотехнологичное производство.

# %% [markdown]
# Рассмотрим результаты исследования отношения к приезжим рабочим, проведенного в Германии.
#
# 3 переменные:
# 1) Возраст (age);
# 2) Отношение к приезжим рабочим (newcomer, от 0 до 30, чем больше значение, тем более негативное отношение);
# 3) Частота посещения церкви (church, 1-никогда, 6-по меньшей мере 2 раза в неделю).

# %%
df1 = pd.read_stata('partial.dta')
df1
# Out:
#     age  church  newcomer
# 0    56       4        17
# 1    80       5        16
# 2    64       4        19
# 3    65       5        19
# 4    48       3        17
# 5    41       3        14
# 6    44       4        21
# 7    43       2        16
# 8    57       4        17
# 9    62       5        18
# 10   44       3        14
# 11   59       4        18
# 12   58       3        19
# 13   55       4        24
# 14   42       3        15
# 15   23       2        16
# 16   65       5        20
# 17   32       3        19
# 18   46       3        15
# 19   34       3        15
# 20   57       3        15
# 21   34       3        13
# 22   30       3         6
# 23   33       2        13
# 24   52       4        19
# 25   51       5        16
# 26   63       6        14
# 27   61       5        29
# 28   51       3        16
# 29   40       2        12
# 30   47       4        20
# 31   38       3        12
# 32   75       6        17
# 33   54       3        15
# 34   66       4        22

# %% [markdown]
# Рассчитаем корреляцию между частотой посещения церкви и отношением к приезжим рабочим.

# %%
stats.kendalltau(df1.church, df1.newcomer)
# Out:
# SignificanceResult(statistic=0.413158691042416, pvalue=0.0020961003342962674)

# %% [markdown]
# Корреляция слабая, но статистически значимая. Следовательно, чем чаще респондент посещает церковь, тем хуже он относится к приезжим рабочим. Это странный результат. Проконтролируем влияние возраста на эту корреляцию.

# %%
pg.partial_corr(data=df1, x='church', y='newcomer', covar='age')
# Out:
#           n        r          CI95%     p-val
# pearson  35  0.12149  [-0.23, 0.44]  0.493692

# %% [markdown]
# Частная корреляция значительно меньше и статически незначима. Скорее всего негативное отношение более свойственно пожилым людям, но так получилось, что они чаще посещают церковь.

# %%
plt.figure(figsize=(6, 6))

plt.scatter(df1.church, df1.newcomer, c='g', alpha=0.7, label='r_xy')
plt.scatter(df1.church, df1.age, c='b', alpha=0.7, label='r_xz')
plt.scatter(df1.newcomer, df1.age, c='r', alpha=0.7, label='r_yz')
plt.title('Correlations', fontsize=18)
plt.legend()
plt.show()

# %% [markdown]
# # 6. Визуализация корреляций<a class="anchor" id="chapter6"></a>

# %%
corr = df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']].dropna().corr(numeric_only=True)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a6e83_row0_col0, #T_a6e83_row1_col1, #T_a6e83_row2_col2, #T_a6e83_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a6e83_row0_col1, #T_a6e83_row0_col3, #T_a6e83_row1_col0, #T_a6e83_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a6e83_row0_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a6e83_row1_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_a6e83_row2_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a6e83_row2_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a6e83_row2_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a6e83_row3_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_a6e83_row3_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a6e83_row3_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a6e83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6e83_level0_col0" class="col_heading level0 col0" >Creative goods and services_2022</th>
#       <th id="T_a6e83_level0_col1" class="col_heading level0 col1" >Business environment_2022</th>
#       <th id="T_a6e83_level0_col2" class="col_heading level0 col2" >Government effectiveness_2022</th>
#       <th id="T_a6e83_level0_col3" class="col_heading level0 col3" >University-industry R&D collaboration_2022</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6e83_level0_row0" class="row_heading level0 row0" >Creative goods and services_2022</th>
#       <td id="T_a6e83_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a6e83_row0_col1" class="data row0 col1" >0.400947</td>
#       <td id="T_a6e83_row0_col2" class="data row0 col2" >0.687971</td>
#       <td id="T_a6e83_row0_col3" class="data row0 col3" >0.544774</td>
#     </tr>
#     <tr>
#       <th id="T_a6e83_level0_row1" class="row_heading level0 row1" >Business environment_2022</th>
#       <td id="T_a6e83_row1_col0" class="data row1 col0" >0.400947</td>
#       <td id="T_a6e83_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a6e83_row1_col2" class="data row1 col2" >0.674534</td>
#       <td id="T_a6e83_row1_col3" class="data row1 col3" >0.759305</td>
#     </tr>
#     <tr>
#       <th id="T_a6e83_level0_row2" class="row_heading level0 row2" >Government effectiveness_2022</th>
#       <td id="T_a6e83_row2_col0" class="data row2 col0" >0.687971</td>
#       <td id="T_a6e83_row2_col1" class="data row2 col1" >0.674534</td>
#       <td id="T_a6e83_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a6e83_row2_col3" class="data row2 col3" >0.735465</td>
#     </tr>
#     <tr>
#       <th id="T_a6e83_level0_row3" class="row_heading level0 row3" >University-industry R&D collaboration_2022</th>
#       <td id="T_a6e83_row3_col0" class="data row3 col0" >0.544774</td>
#       <td id="T_a6e83_row3_col1" class="data row3 col1" >0.759305</td>
#       <td id="T_a6e83_row3_col2" class="data row3 col2" >0.735465</td>
#       <td id="T_a6e83_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.heatmap(df.corr(numeric_only=True))  # тепловая карта
# Out:
# <Axes: >

# %%
sns.heatmap(df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']]
            .corr(), annot=True)  # с метками значений
# Out:
# <Axes: >

# %%
sns.heatmap(df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']].corr(), annot=True, cmap='RdYlGn')
# другая цветовая шкала
# Out:
# <Axes: >

# %%
sns.heatmap(df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']].corr(), annot=True, cmap='RdYlGn', vmax=1, vmin=-1) 
# заданы минимальные и максимальные значения шкалы
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))  # скорректирован размер
sns.heatmap(df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']].corr(), annot=True, cmap='RdYlGn', vmax=1, vmin=-1)
# Out:
# <Axes: >

# %%
df1 = df[['Creative goods and services_2022','Business environment_2022','Government effectiveness_2022', 'University-industry R&D collaboration_2022']]
rho = df1.corr()
pval = df1.corr(method=lambda x, y: stats.pearsonr(x, y)[1]) - np.eye(*rho.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [.05, .01, .001] if x<=t]))
rho.round(2).astype(str) + p
# Out:
#                                            Creative goods and services_2022  \
# Creative goods and services_2022                                     1.0***
# Business environment_2022                                            0.4***
# Government effectiveness_2022                                       0.69***
# University-industry R&D collaboration_2022                          0.54***
#
#                                            Business environment_2022  \
# Creative goods and services_2022                              0.4***
# Business environment_2022                                     1.0***
# Government effectiveness_2022                                0.67***
# University-industry R&D collaboration_2022                   0.76***
#
#                                            Government effectiveness_2022  \
# Creative goods and services_2022                                 0.69***
# Business environment_2022                                        0.67***
# Government effectiveness_2022                                     1.0***
# University-industry R&D collaboration_2022                       0.74***
#
#                                            University-industry R&D collaboration_2022
# Creative goods and services_2022                                              0.54***
# Business environment_2022                                                     0.76***
# Government effectiveness_2022                                                 0.74***
# University-industry R&D collaboration_2022                                     1.0***

# %% [markdown]
# Звездочками помечена статистическая значимость: * - p < 0.1; ** - p < 0.05; *** - p < 0.01
